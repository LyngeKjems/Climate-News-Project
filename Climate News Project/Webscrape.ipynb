# %%
import requests
import time
import tqdm
import pandas as pd
import os
import json
from bs4 import BeautifulSoup

# %%
# Set the option to display DataFrame columns without truncation
pd.set_option('display.max_colwidth', None)

# List of search terms
search_terms = [
    "Klimaforandringer", "CO2-udledning"
]

# Number of pages to scrape for each term
num_pages = 1

data = {"Term": [], "Date": [], "Headline": [], "Category": []}

for term in search_terms:
    for page in range(1, num_pages + 1):
        url = f'https://jyllands-posten.dk/soeg/?term={term}&sort=newest&page={page}'

        try:
            response = requests.get(url)
            response.raise_for_status()

            soup = BeautifulSoup(response.content, "html.parser")

            date_elements = soup.find_all("time", class_="pl-1")
            headline_elements = soup.find_all("h2", class_="font-article-heading text-lg font-medium leading-snug group-hover:underline md:text-2xl")
            category_elements = soup.find_all("span", class_="pr-1")

            if date_elements:
                for date_element in date_elements:
                    date = date_element.text.strip()
                    data["Term"].append(term)
                    data["Date"].append(date)
            else:
                print(f"No dates found for {term} on page {page}.")

            if headline_elements:
                for headline_element in headline_elements:
                    headline = headline_element.text.strip()
                    data["Headline"].append(headline)
            else:
                print(f"No headlines found for {term} on page {page}.")
            
            if category_elements:
                for category_element in category_elements:
                    category = category_element.text.strip()
                    data["Category"].append(category)
            else:
                print(f"No category found for {term} on page {page}.")
            
        except requests.RequestException as e:
            print("Error fetching the web page:", e)
        except Exception as e:
            print("An error occurred:", e)

# Create a pandas DataFrame from the combined dictionary
df = pd.DataFrame(data)
df

df.to_csv('jyllands_posten.csv', index=False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import time
import locale

# Set the locale to Danish for month name parsing
locale.setlocale(locale.LC_TIME, 'da_DK.utf8')

# Set the option to display DataFrame columns without truncation
pd.set_option('display.max_colwidth', None)

# List of search terms
search_terms = [
    "CO2-mål", "CO2-reduktion", "CO2-udledning", "CO2-udledninger",
    "global opvarmning", "havstigning", "havstigninger", "klimaaftryk",
    "klimaangst", "klimaforandring", "klimaforandringer", "klimakrise",
    "klimakrisen", "klimasynder"
]

data = {"Term": [], "Date": [], "Headline": [], "Category": []}

target_date = datetime.strptime("1. januar 2011", "%d. %B %Y")
target_date_str = target_date.strftime("%d. %B %Y")

# Your custom User-Agent string
headers = {
    'User-Agent': 'Student from Copenhagen University - vmn430@alumni.ku.dk'
}

for term in search_terms:
    page = 1
    while True:
        url = f'https://jyllands-posten.dk/soeg/?term={term}&sort=newest&page={page}'

        try:
            # Include the custom headers in your request
            response = requests.get(url, headers=headers)
            response.raise_for_status()

            soup = BeautifulSoup(response.content, "html.parser")

            date_elements = soup.find_all("time", class_="pl-1")
            headline_elements = soup.find_all("h2", class_="font-article-heading text-lg font-medium leading-snug group-hover:underline md:text-2xl")
            category_elements = soup.find_all("span", class_="pr-1")

            if date_elements:
                for date_element, headline_element, category_element in zip(date_elements, headline_elements, category_elements):
                    date_str = date_element.text.strip()
                    date = datetime.strptime(date_str, "%d. %B %Y")
                    if date >= target_date:
                        data["Term"].append(term)
                        data["Date"].append(date_str)
                        data["Headline"].append(headline_element.text.strip())
                        data["Category"].append(category_element.text.strip())
                        print(f"Appended: {term} | {date_str}")  # Debugging
                    else:
                        break
            else:
                print(f"No dates found for {term} on page {page}.")

            page += 1  # Move to the next page

            # Introduce a delay of 0.5 second before making the next request
            time.sleep(0.5)

            # Check if the scraped date is before the target date
            if date < target_date:
                break

        except requests.RequestException as e:
            print("Error fetching the web page:", e)
        except Exception as e:
            print("An error occurred:", e)

# Create a pandas DataFrame from the combined dictionary
df = pd.DataFrame(data)

# Sort the DataFrame by Date
df["Date"] = pd.to_datetime(df["Date"], format="%d. %B %Y")
df = df.sort_values("Date", ascending=True)

df.to_csv('jyllands_posten_data.csv', index=False)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import time
import locale

# Set the locale to Danish for month name parsing
locale.setlocale(locale.LC_TIME, 'da_DK.utf8')

# Set the option to display DataFrame columns without truncation
pd.set_option('display.max_colwidth', None)

# List of search terms
search_terms = [
    "CO2-mål", "CO2-reduktion", "CO2-udledning", "CO2-udledninger",
    "global opvarmning", "havstigning", "havstigninger", "klimaaftryk",
    "klimaangst", "klimaforandring", "klimaforandringer", "klimakrise",
    "klimakrisen", "klimasynder"
]

data = {"Term": [], "Date": [], "Headline": [], "Category": []}

target_date = datetime.strptime("1. januar 2011", "%d. %B %Y")

# Your custom User-Agent string
headers = {
    'User-Agent': 'Student from Copenhagen University - vmn430@alumni.ku.dk'
}

for term in search_terms:
    page = 1
    no_dates_found_counter = 0  # Counter to keep track of consecutive pages with no dates found

    while True:
        url = f'https://jyllands-posten.dk/soeg/?term={term}&sort=newest&page={page}'

        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()

            soup = BeautifulSoup(response.content, "html.parser")

            date_elements = soup.find_all("time", class_="pl-1")
            headline_elements = soup.find_all("h2", class_="font-article-heading text-lg font-medium leading-snug group-hover:underline md:text-2xl")
            category_elements = soup.find_all("span", class_="pr-1")

            if not date_elements:
                print(f"No dates found for {term} on page {page}.")
                no_dates_found_counter += 1
                if no_dates_found_counter >= 5:  # Adjust this threshold as needed
                    print(f"Stopping search for {term} after {no_dates_found_counter} consecutive pages with no dates found.")
                    break
            else:  # Reset counter if dates are found
                no_dates_found_counter = 0

            for date_element, headline_element, category_element in zip(date_elements, headline_elements, category_elements):
                date_str = date_element.text.strip()
                date = datetime.strptime(date_str, "%d. %B %Y")
                if date >= target_date:
                    data["Term"].append(term)
                    data["Date"].append(date_str)
                    data["Headline"].append(headline_element.text.strip())
                    data["Category"].append(category_element.text.strip())
                    print(f"Appended: {term} | {date_str}")  # Debugging
                else:
                    break

            page += 1

            # Introduce a delay of 0.5 second before making the next request
            time.sleep(0.5)

            # Check if the scraped date is before the target date
            if date < target_date:
                break

        except requests.RequestException as e:
            print("Error fetching the web page:", e)
        except Exception as e:
            print("An error occurred:", e)

# Create a pandas DataFrame from the combined dictionary
df = pd.DataFrame(data)

# Sort the DataFrame by Date
df["Date"] = pd.to_datetime(df["Date"], format="%d. %B %Y")
df = df.sort_values("Date", ascending=True)

df.to_csv('jyllands_posten_data.csv', index=False)
# Out:
# Appended: CO2-mål | 13. august 2023
# Appended: CO2-mål | 10. august 2023
# Appended: CO2-mål | 10. august 2023
# Appended: CO2-mål | 9. august 2023
# Appended: CO2-mål | 7. august 2023
# Appended: CO2-mål | 7. august 2023
# Appended: CO2-mål | 7. august 2023
# Appended: CO2-mål | 3. august 2023
# Appended: CO2-mål | 1. august 2023
# Appended: CO2-mål | 27. juli 2023
# Appended: CO2-mål | 27. juli 2023
# Appended: CO2-mål | 26. juli 2023
# Appended: CO2-mål | 25. juli 2023
# Appended: CO2-mål | 20. juli 2023
# Appended: CO2-mål | 20. juli 2023
# Appended: CO2-mål | 13. juli 2023
# Appended: CO2-mål | 8. juli 2023
# Appended: CO2-mål | 7. juli 2023
# Appended: CO2-mål | 28. juni 2023
# Appended: CO2-mål | 27. juni 2023
# Appended: CO2-mål | 22. juni 2023
# Appended: CO2-mål | 21. juni 2023
# Appended: CO2-mål | 20. juni 2023
# Appended: CO2-mål | 19. juni 2023
# Appended: CO2-mål | 19. juni 2023
# Appended: CO2-mål | 15. juni 2023
# Appended: CO2-mål | 15. juni 2023
# Appended: CO2-mål | 15. juni 2023
# Appended: CO2-mål | 14. juni 2023
# Appended: CO2-mål | 13. juni 2023
# Appended: CO2-mål | 10. juni 2023
# Appended: CO2-mål | 9. juni 2023
# Appended: CO2-mål | 7. juni 2023
# Appended: CO2-mål | 1. juni 2023
# Appended: CO2-mål | 30. maj 2023
# Appended: CO2-mål | 29. maj 2023
# Appended: CO2-mål | 29. maj 2023
# Appended: CO2-mål | 26. maj 2023
# Appended: CO2-mål | 23. maj 2023
# Appended: CO2-mål | 23. maj 2023
# Appended: CO2-mål | 23. maj 2023
# Appended: CO2-mål | 20. maj 2023
# Appended: CO2-mål | 19. maj 2023
# Appended: CO2-mål | 18. maj 2023
# Appended: CO2-mål | 16. maj 2023
# Appended: CO2-mål | 15. maj 2023
# Appended: CO2-mål | 13. maj 2023
# Appended: CO2-mål | 10. maj 2023
# Appended: CO2-mål | 8. maj 2023
# Appended: CO2-mål | 8. maj 2023
# Appended: CO2-mål | 6. maj 2023
# Appended: CO2-mål | 6. maj 2023
# Appended: CO2-mål | 1. maj 2023
# Appended: CO2-mål | 29. april 2023
# Appended: CO2-mål | 29. april 2023
# Appended: CO2-mål | 28. april 2023
# Appended: CO2-mål | 27. april 2023
# Appended: CO2-mål | 23. april 2023
# Appended: CO2-mål | 21. april 2023
# Appended: CO2-mål | 21. april 2023
# Appended: CO2-mål | 20. april 2023
# Appended: CO2-mål | 20. april 2023
# Appended: CO2-mål | 19. april 2023
# Appended: CO2-mål | 19. april 2023
# Appended: CO2-mål | 17. april 2023
# Appended: CO2-mål | 16. april 2023
# Appended: CO2-mål | 12. april 2023
# Appended: CO2-mål | 4. april 2023
# Appended: CO2-mål | 29. marts 2023
# Appended: CO2-mål | 27. marts 2023
# Appended: CO2-mål | 27. marts 2023
# Appended: CO2-mål | 25. marts 2023
# Appended: CO2-mål | 25. marts 2023
# Appended: CO2-mål | 20. marts 2023
# Appended: CO2-mål | 20. marts 2023
# Appended: CO2-mål | 20. marts 2023
# Appended: CO2-mål | 13. marts 2023
# Appended: CO2-mål | 9. marts 2023
# Appended: CO2-mål | 8. marts 2023
# Appended: CO2-mål | 7. marts 2023
# Appended: CO2-mål | 7. september 2020
# Appended: CO2-mål | 7. september 2020
# Appended: CO2-mål | 5. september 2020
# Appended: CO2-mål | 2. september 2020
# Appended: CO2-mål | 2. september 2020
# Appended: CO2-mål | 1. september 2020
# Appended: CO2-mål | 31. august 2020
# Appended: CO2-mål | 30. august 2020
# Appended: CO2-mål | 26. august 2020
# Appended: CO2-mål | 23. august 2020
# Appended: CO2-mål | 14. august 2020
# Appended: CO2-mål | 12. august 2020
# Appended: CO2-mål | 12. august 2020
# Appended: CO2-mål | 12. august 2020
# Appended: CO2-mål | 6. august 2020
# Appended: CO2-mål | 1. august 2020
# Appended: CO2-mål | 29. juli 2020
# Appended: CO2-mål | 28. juli 2020
# Appended: CO2-mål | 22. juli 2020
# Appended: CO2-mål | 20. juli 2020
# Appended: CO2-mål | 9. juli 2020
# Appended: CO2-mål | 8. juli 2020
# Appended: CO2-mål | 8. juli 2020
# Appended: CO2-mål | 7. juli 2020
# Appended: CO2-mål | 7. juli 2020
# Appended: CO2-mål | 5. juli 2020
# Appended: CO2-mål | 4. juli 2020
# Appended: CO2-mål | 2. juli 2020
# Appended: CO2-mål | 1. juli 2020
# Appended: CO2-mål | 30. juni 2020
# Appended: CO2-mål | 29. juni 2020
# Appended: CO2-mål | 26. juni 2020
# Appended: CO2-mål | 25. juni 2020
# Appended: CO2-mål | 24. juni 2020
# Appended: CO2-mål | 23. juni 2020
# Appended: CO2-mål | 22. juni 2020
# Appended: CO2-mål | 22. juni 2020
# Appended: CO2-mål | 22. juni 2020
# Appended: CO2-mål | 22. juni 2020
# Appended: CO2-mål | 22. juni 2020
# Appended: CO2-mål | 21. juni 2020
# Appended: CO2-mål | 21. juni 2020
# Appended: CO2-mål | 20. juni 2020
# Appended: CO2-mål | 19. juni 2020
# Appended: CO2-mål | 18. juni 2020
# Appended: CO2-mål | 17. juni 2020
# Appended: CO2-mål | 12. juni 2020
# Appended: CO2-mål | 11. juni 2020
# Appended: CO2-mål | 9. juni 2020
# Appended: CO2-mål | 8. juni 2020
# Appended: CO2-mål | 7. juni 2020
# Appended: CO2-mål | 5. juni 2020
# Appended: CO2-mål | 5. juni 2020
# Appended: CO2-mål | 4. juni 2020
# Appended: CO2-mål | 4. juni 2020
# Appended: CO2-mål | 4. juni 2020
# Appended: CO2-mål | 4. juni 2020
# Appended: CO2-mål | 3. juni 2020
# Appended: CO2-mål | 26. maj 2020
# Appended: CO2-mål | 26. maj 2020
# Appended: CO2-mål | 25. maj 2020
# Appended: CO2-mål | 22. maj 2020
# Appended: CO2-mål | 21. maj 2020
# Appended: CO2-mål | 20. maj 2020
# Appended: CO2-mål | 20. maj 2020
# Appended: CO2-mål | 20. maj 2020
# Appended: CO2-mål | 19. maj 2020
# Appended: CO2-mål | 19. maj 2020
# Appended: CO2-mål | 17. maj 2020
# Appended: CO2-mål | 17. maj 2020
# Appended: CO2-mål | 17. maj 2020
# Appended: CO2-mål | 16. maj 2020
# Appended: CO2-mål | 13. maj 2020
# Appended: CO2-mål | 10. maj 2020
# Appended: CO2-mål | 6. maj 2020
# Appended: CO2-mål | 12. januar 2020
# Appended: CO2-mål | 12. januar 2020
# Appended: CO2-mål | 11. januar 2020
# Appended: CO2-mål | 10. januar 2020
# Appended: CO2-mål | 10. januar 2020
# Appended: CO2-mål | 9. januar 2020
# Appended: CO2-mål | 8. januar 2020
# Appended: CO2-mål | 8. januar 2020
# Appended: CO2-mål | 7. januar 2020
# Appended: CO2-mål | 5. januar 2020
# Appended: CO2-mål | 4. januar 2020
# Appended: CO2-mål | 2. januar 2020
# Appended: CO2-mål | 1. januar 2020
# Appended: CO2-mål | 1. januar 2020
# Appended: CO2-mål | 31. december 2019
# Appended: CO2-mål | 31. december 2019
# Appended: CO2-mål | 28. december 2019
# Appended: CO2-mål | 23. december 2019
# Appended: CO2-mål | 23. december 2019
# Appended: CO2-mål | 22. december 2019
# Appended: CO2-mål | 20. december 2019
# Appended: CO2-mål | 20. december 2019
# Appended: CO2-mål | 18. december 2019
# Appended: CO2-mål | 17. december 2019
# Appended: CO2-mål | 16. december 2019
# Appended: CO2-mål | 15. december 2019
# Appended: CO2-mål | 13. december 2019
# Appended: CO2-mål | 13. december 2019
# Appended: CO2-mål | 12. december 2019
# Appended: CO2-mål | 12. december 2019
# Appended: CO2-mål | 11. december 2019
# Appended: CO2-mål | 11. december 2019
# Appended: CO2-mål | 9. december 2019
# Appended: CO2-mål | 8. december 2019
# Appended: CO2-mål | 7. december 2019
# Appended: CO2-mål | 7. december 2019
# Appended: CO2-mål | 7. december 2019
# Appended: CO2-mål | 6. december 2019
# Appended: CO2-mål | 6. december 2019
# Appended: CO2-mål | 6. december 2019
# Appended: CO2-mål | 6. december 2019
# Appended: CO2-mål | 5. december 2019
# Appended: CO2-mål | 3. december 2019
# Appended: CO2-mål | 2. december 2019
# Appended: CO2-mål | 1. december 2019
# Appended: CO2-mål | 1. december 2019
# Appended: CO2-mål | 1. december 2019
# Appended: CO2-mål | 1. december 2019
# Appended: CO2-mål | 1. december 2019
# Appended: CO2-mål | 30. november 2019
# Appended: CO2-mål | 30. november 2019
# Appended: CO2-mål | 29. november 2019
# Appended: CO2-mål | 28. november 2019
# Appended: CO2-mål | 27. november 2019
# Appended: CO2-mål | 27. november 2019
# Appended: CO2-mål | 27. november 2019
# Appended: CO2-mål | 26. november 2019
# Appended: CO2-mål | 26. november 2019
# Appended: CO2-mål | 26. november 2019
# Appended: CO2-mål | 25. november 2019
# Appended: CO2-mål | 25. november 2019
# Appended: CO2-mål | 23. november 2019
# Appended: CO2-mål | 23. november 2019
# Appended: CO2-mål | 21. november 2019
# Appended: CO2-mål | 18. november 2019
# Appended: CO2-mål | 14. november 2019
# Appended: CO2-mål | 14. november 2019
# Appended: CO2-mål | 12. november 2019
# Appended: CO2-mål | 10. november 2019
# Appended: CO2-mål | 3. november 2019
# Appended: CO2-mål | 2. november 2019
# Appended: CO2-mål | 2. november 2019
# Appended: CO2-mål | 1. november 2019
# Appended: CO2-mål | 29. oktober 2019
# Appended: CO2-mål | 26. oktober 2019
# Appended: CO2-mål | 25. oktober 2019
# Appended: CO2-mål | 8. august 2019
# Appended: CO2-mål | 6. august 2019
# Appended: CO2-mål | 4. august 2019
# Appended: CO2-mål | 28. juli 2019
# Appended: CO2-mål | 25. juli 2019
# Appended: CO2-mål | 20. juli 2019
# Appended: CO2-mål | 19. juli 2019
# Appended: CO2-mål | 19. juli 2019
# Appended: CO2-mål | 17. juli 2019
# Appended: CO2-mål | 16. juli 2019
# Appended: CO2-mål | 16. juli 2019
# Appended: CO2-mål | 14. juli 2019
# Appended: CO2-mål | 12. juli 2019
# Appended: CO2-mål | 10. juli 2019
# Appended: CO2-mål | 10. juli 2019
# Appended: CO2-mål | 7. juli 2019
# Appended: CO2-mål | 5. juli 2019
# Appended: CO2-mål | 4. juli 2019
# Appended: CO2-mål | 3. juli 2019
# Appended: CO2-mål | 2. juli 2019
# Appended: CO2-mål | 1. juli 2019
# Appended: CO2-mål | 29. juni 2019
# Appended: CO2-mål | 26. juni 2019
# Appended: CO2-mål | 26. juni 2019
# Appended: CO2-mål | 23. juni 2019
# Appended: CO2-mål | 23. juni 2019
# Appended: CO2-mål | 22. juni 2019
# Appended: CO2-mål | 22. juni 2019
# Appended: CO2-mål | 21. juni 2019
# Appended: CO2-mål | 21. juni 2019
# Appended: CO2-mål | 21. juni 2019
# Appended: CO2-mål | 20. juni 2019
# Appended: CO2-mål | 20. juni 2019
# Appended: CO2-mål | 20. juni 2019
# Appended: CO2-mål | 20. juni 2019
# Appended: CO2-mål | 20. juni 2019
# Appended: CO2-mål | 20. juni 2019
# Appended: CO2-mål | 19. juni 2019
# Appended: CO2-mål | 19. juni 2019
# Appended: CO2-mål | 19. juni 2019
# Appended: CO2-mål | 19. juni 2019
# Appended: CO2-mål | 19. juni 2019
# Appended: CO2-mål | 16. juni 2019
# Appended: CO2-mål | 16. juni 2019
# Appended: CO2-mål | 15. juni 2019
# Appended: CO2-mål | 15. juni 2019
# Appended: CO2-mål | 14. juni 2019
# Appended: CO2-mål | 12. juni 2019
# Appended: CO2-mål | 11. juni 2019
# Appended: CO2-mål | 8. juni 2019
# Appended: CO2-mål | 8. juni 2019
# Appended: CO2-mål | 7. juni 2019
# Appended: CO2-mål | 6. juni 2019
# Appended: CO2-mål | 4. juni 2019
# Appended: CO2-mål | 3. juni 2019
# Appended: CO2-mål | 3. juni 2019
# Appended: CO2-mål | 3. juni 2019
# Appended: CO2-mål | 30. maj 2019
# Appended: CO2-mål | 29. maj 2019
# Appended: CO2-mål | 28. maj 2019
# Appended: CO2-mål | 28. maj 2019
# Appended: CO2-mål | 28. maj 2019
# Appended: CO2-mål | 26. maj 2019
# Appended: CO2-mål | 25. maj 2019
# Appended: CO2-mål | 25. maj 2019
# Appended: CO2-mål | 25. maj 2019
# Appended: CO2-mål | 25. maj 2019
# Appended: CO2-mål | 24. maj 2019
# Appended: CO2-mål | 22. maj 2019
# Appended: CO2-mål | 21. maj 2019
# Appended: CO2-mål | 20. maj 2019
# Appended: CO2-mål | 19. maj 2019
# Appended: CO2-mål | 19. maj 2019
# Appended: CO2-mål | 19. maj 2019
# Appended: CO2-mål | 19. maj 2019
# Appended: CO2-mål | 19. maj 2019
# Appended: CO2-mål | 18. maj 2019
# Appended: CO2-mål | 18. maj 2019
# Appended: CO2-mål | 16. maj 2019
# Appended: CO2-mål | 15. maj 2019
# Appended: CO2-mål | 14. maj 2019
# Appended: CO2-mål | 13. maj 2019
# Appended: CO2-mål | 12. maj 2019
# Appended: CO2-mål | 10. maj 2019
# Appended: CO2-mål | 10. maj 2019
# Appended: CO2-mål | 9. maj 2019
# Appended: CO2-mål | 9. maj 2019
# Appended: CO2-mål | 7. maj 2019
# Appended: CO2-mål | 7. maj 2019
# Appended: CO2-mål | 7. maj 2019
# Appended: CO2-mål | 7. maj 2019
# Appended: CO2-mål | 6. maj 2019
# Appended: CO2-mål | 5. maj 2019
# Appended: CO2-mål | 4. maj 2019
# Appended: CO2-mål | 3. maj 2019
# Appended: CO2-mål | 30. april 2019
# Appended: CO2-mål | 30. april 2019
# Appended: CO2-mål | 30. april 2019
# Appended: CO2-mål | 29. april 2019
# Appended: CO2-mål | 29. april 2019
# Appended: CO2-mål | 29. april 2019
# Appended: CO2-mål | 26. april 2019
# Appended: CO2-mål | 25. april 2019
# Appended: CO2-mål | 24. april 2019
# Appended: CO2-mål | 22. april 2019
# Appended: CO2-mål | 22. april 2019
# Appended: CO2-mål | 21. april 2019
# Appended: CO2-mål | 19. april 2019
# Appended: CO2-mål | 19. april 2019
# Appended: CO2-mål | 16. april 2019
# Appended: CO2-mål | 15. april 2019
# Appended: CO2-mål | 14. april 2019
# Appended: CO2-mål | 13. april 2019
# Appended: CO2-mål | 11. april 2019
# Appended: CO2-mål | 11. april 2019
# Appended: CO2-mål | 10. april 2019
# Appended: CO2-mål | 9. april 2019
# Appended: CO2-mål | 2. april 2019
# Appended: CO2-mål | 2. april 2019
# Appended: CO2-mål | 31. marts 2019
# Appended: CO2-mål | 29. marts 2019
# Appended: CO2-mål | 28. marts 2019
# Appended: CO2-mål | 28. marts 2019
# Appended: CO2-mål | 27. marts 2019
# Appended: CO2-mål | 26. marts 2019
# Appended: CO2-mål | 25. marts 2019
# Appended: CO2-mål | 24. marts 2019
# Appended: CO2-mål | 21. marts 2019
# Appended: CO2-mål | 20. marts 2019
# Appended: CO2-mål | 17. marts 2019
# Appended: CO2-mål | 15. marts 2019
# Appended: CO2-mål | 11. marts 2019
# Appended: CO2-mål | 5. marts 2019
# Appended: CO2-mål | 4. marts 2019
# Appended: CO2-mål | 3. marts 2019
# Appended: CO2-mål | 1. marts 2019
# Appended: CO2-mål | 1. marts 2019
# Appended: CO2-mål | 27. februar 2019
# Appended: CO2-mål | 21. februar 2019
# Appended: CO2-mål | 16. februar 2019
# Appended: CO2-mål | 14. februar 2019
# Appended: CO2-mål | 10. februar 2019
# Appended: CO2-mål | 9. februar 2019
# Appended: CO2-mål | 7. februar 2019
# Appended: CO2-mål | 5. februar 2019
# Appended: CO2-mål | 3. februar 2019
# Appended: CO2-mål | 3. februar 2019
# Appended: CO2-mål | 31. januar 2019
# Appended: CO2-mål | 30. januar 2019
# Appended: CO2-mål | 29. januar 2019
# Appended: CO2-mål | 28. januar 2019
# Appended: CO2-mål | 26. januar 2019
# Appended: CO2-mål | 26. januar 2019
# Appended: CO2-mål | 21. januar 2019
# Appended: CO2-mål | 21. januar 2019
# Appended: CO2-mål | 19. januar 2019
# Appended: CO2-mål | 17. januar 2019
# Appended: CO2-mål | 9. januar 2019
# Appended: CO2-mål | 8. januar 2019
# Appended: CO2-mål | 31. december 2018
# Appended: CO2-mål | 27. december 2018
# Appended: CO2-mål | 22. december 2018
# Appended: CO2-mål | 21. december 2018
# Appended: CO2-mål | 20. december 2018
# Appended: CO2-mål | 19. december 2018
# Appended: CO2-mål | 17. december 2018
# Appended: CO2-mål | 16. december 2018
# Appended: CO2-mål | 15. december 2018
# Appended: CO2-mål | 14. december 2018
# Appended: CO2-mål | 13. december 2018
# Appended: CO2-mål | 13. december 2018
# Appended: CO2-mål | 13. december 2018
# Appended: CO2-mål | 12. december 2018
# Appended: CO2-mål | 12. december 2018
# Appended: CO2-mål | 12. december 2018
# Appended: CO2-mål | 11. december 2018
# Appended: CO2-mål | 10. december 2018
# Appended: CO2-mål | 5. december 2018
# Appended: CO2-mål | 29. november 2018
# Appended: CO2-mål | 28. november 2018
# Appended: CO2-mål | 28. november 2018
# Appended: CO2-mål | 28. november 2018
# Appended: CO2-mål | 28. november 2018
# Appended: CO2-mål | 27. november 2018
# Appended: CO2-mål | 27. november 2018
# Appended: CO2-mål | 26. november 2018
# Appended: CO2-mål | 24. november 2018
# Appended: CO2-mål | 23. november 2018
# Appended: CO2-mål | 23. november 2018
# Appended: CO2-mål | 9. november 2018
# Appended: CO2-mål | 1. november 2018
# Appended: CO2-mål | 22. oktober 2018
# Appended: CO2-mål | 19. oktober 2018
# Appended: CO2-mål | 12. oktober 2018
# Appended: CO2-mål | 10. oktober 2018
# Appended: CO2-mål | 10. oktober 2018
# Appended: CO2-mål | 9. oktober 2018
# Appended: CO2-mål | 9. oktober 2018
# Appended: CO2-mål | 9. oktober 2018
# Appended: CO2-mål | 9. oktober 2018
# Appended: CO2-mål | 9. oktober 2018
# Appended: CO2-mål | 9. oktober 2018
# Appended: CO2-mål | 9. oktober 2018
# Appended: CO2-mål | 8. oktober 2018
# Appended: CO2-mål | 8. oktober 2018
# Appended: CO2-mål | 8. oktober 2018
# Appended: CO2-mål | 8. oktober 2018
# Appended: CO2-mål | 5. oktober 2018
# Appended: CO2-mål | 3. oktober 2018
# Appended: CO2-mål | 2. oktober 2018
# Appended: CO2-mål | 2. oktober 2018
# Appended: CO2-mål | 2. oktober 2018
# Appended: CO2-mål | 2. oktober 2018
# ...
# Appended: klimakrisen | 7. december 2019
# Appended: klimakrisen | 5. december 2019
# Appended: klimakrisen | 3. december 2019
# Appended: klimakrisen | 3. december 2019
# Appended: klimakrisen | 2. december 2019
# Appended: klimakrisen | 1. december 2019
# Appended: klimakrisen | 28. november 2019
# Appended: klimakrisen | 28. november 2019
# Appended: klimakrisen | 26. november 2019
# Appended: klimakrisen | 21. november 2019
# Appended: klimakrisen | 20. november 2019
# Appended: klimakrisen | 18. november 2019
# Appended: klimakrisen | 12. november 2019
# Appended: klimakrisen | 12. november 2019
# Appended: klimakrisen | 7. november 2019
# Appended: klimakrisen | 7. november 2019
# Appended: klimakrisen | 7. november 2019
# Appended: klimakrisen | 7. november 2019
# Appended: klimakrisen | 6. november 2019
# Appended: klimakrisen | 6. november 2019
# Appended: klimakrisen | 6. november 2019
# Appended: klimakrisen | 5. november 2019
# Appended: klimakrisen | 2. november 2019
# Appended: klimakrisen | 2. november 2019
# Appended: klimakrisen | 1. november 2019
